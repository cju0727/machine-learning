# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
데이터 = pd.read_csv(파일경로)
데이터.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 종속변수, 독립변수
독립 = 데이터[['온도']]
종속 = 데이터[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 모델을 만든다
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 모델 학습
model.fit(독립, 종속, epochs = 10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6375e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6379e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6380e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6380e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6383e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6374e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6362e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6347e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6336e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6332e-04

# %%
# 모델 적용
model.predict([[15]])
# Out:
# array([[30.03012]], dtype=float32)
