# %%
# 사용할 라이브러리를 불러온다.
import tensorflow as tf
import pandas as pd

# %%
# 실습을 위해 준비된 데이터를 불러오고 간단히 출력해본다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)
아이리스.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %%
# 회귀가 아니라 분류를 사용해야하므로 원 핫 인코딩을 사용한다.
인코딩 = pd.get_dummies(아이리스)
인코딩.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_setosa  품종_versicolor  품종_virginica
# 0   5.1  3.5    1.4   0.2          1              0             0
# 1   4.9  3.0    1.4   0.2          1              0             0
# 2   4.7  3.2    1.3   0.2          1              0             0
# 3   4.6  3.1    1.5   0.2          1              0             0
# 4   5.0  3.6    1.4   0.2          1              0             0

# %%
# 독립변수와 종속변수를 나눠준다.
독립 = 인코딩[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = 인코딩[['품종_setosa', '품종_versicolor', '품종_virginica']]

print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
# 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[4])
Y = tf.keras.layers.Dense(3, activation = 'softmax')(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss = 'categorical_crossentropy', metrics = 'accuracy')

# %%
# 데이터로 모델을 학습한다.
model.fit(독립, 종속, epochs = 10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4074 - accuracy: 0.9000
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.8933
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.9133
# Epoch 4/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4047 - accuracy: 0.9000
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4039 - accuracy: 0.9200
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.9067
# Epoch 7/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.9133
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.9067
# Epoch 9/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4002 - accuracy: 0.9133
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.9267

# %%
# 학습된 모델을 이용해 예측한다.
model.predict(독립[-5:])
# Out:
# array([[0.01187386, 0.38582814, 0.60229796],
#        [0.01266372, 0.45839545, 0.52894086],
#        [0.0132901 , 0.38160166, 0.6051082 ],
#        [0.00666562, 0.19699872, 0.7963357 ],
#        [0.01161503, 0.28712678, 0.7012582 ]], dtype=float32)

# %%
# 실제 정답과 비교해본다.
print(종속[-5:])
# Out:
#      품종_setosa  품종_versicolor  품종_virginica
# 145          0              0             1
# 146          0              0             1
# 147          0              0             1
# 148          0              0             1
# 149          0              0             1
